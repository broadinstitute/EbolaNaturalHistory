# %% [markdown]
# ## Ebola infected Macaque Sample Composition Trajectory Identification
#
# In this notebook we deconvolve the ebov macaque blood samples using a matched seq-well reference.

# %% [raw]
# %load_ext autoreload
# %autoreload 2

# %%
import matplotlib.pylab as plt

# %%
import anndata

# %%
import torch
from ternadecov.time_deconv import *
from ternadecov.simulator import *
from ternadecov.stats_helpers import *
from ternadecov.dataset import *

# %% [markdown]
# # Configuration

# %%
device = torch.device("cuda:0")
dtype = torch.float32
dtype_np = np.float32
n_iters = 20_000

# %% [markdown]
# # Load data

# %%
location_fascicularis = '/home/nbarkas/disk1/work/deconvolution_method/datasets/ebov/fascicularis/'

h5ad_paths = {
    # Ebov Datasets
    "bulk_blood": "ebov_bulk.h5ad",
    "sc_blood": "/home/nbarkas/disk1/work/deconvolution_method/datasets/ebov/load_data_python/ebov_sc.h5ad",
    "bulk_all": "/home/nbarkas/disk1/work/deconvolution_method/datasets/ebov/all_ebov_bulk.h5ad",
    
    # fascicularis
    "sc_adrenal": f"{location_fascicularis}/Adrenal_gland.h5ad",
    "sc_cerebellum": f"{location_fascicularis}/Cerebellum.h5ad",
    "sc_kidney": f"{location_fascicularis}/Kidney.h5ad",
    "sc_liver": f"{location_fascicularis}/Liver.h5ad",
    "sc_lung": f"{location_fascicularis}/lung.h5ad",
    "sc_lymph_node": f"{location_fascicularis}/Lymph_node.h5ad",
    "sc_neocortex": f"{location_fascicularis}/Neocortex.h5ad",
    "sc_pbmc": f"{location_fascicularis}/pbmc.h5ad",
    "sc_skin": f"{location_fascicularis}/Skin.h5ad",
    "sc_spleen": f"{location_fascicularis}/Spleen.h5ad",
    "sc_subcutaneous_adipose": f"{location_fascicularis}/Subcutaneous_adipose.h5ad",
    "sc_testis": f"{location_fascicularis}/Testis.h5ad",
    "sc_thyroid": f"{location_fascicularis}/Thyroid_gland.h5ad",
    "sc_uterus": f"{location_fascicularis}/Uterus.h5ad",
    "sc_vagina": f"{location_fascicularis}/Vagina.h5ad",
}

# %%
with open(h5ad_paths['bulk_all'], 'rb') as fh:
    all_bulk_anndata = anndata.read_h5ad(fh)

# %%
with open(h5ad_paths['sc_skin'], 'rb') as fh:
    sc_anndata = anndata.read_h5ad(fh)

# %%
set(all_bulk_anndata.obs['full.tissue'])
# Out:
# {'Adrenal Gland',
#  'Brain:Brain-Gr',
#  'Brain:Brain-Wh',
#  'Kidney',
#  'Liver',
#  'Lung',
#  'Lymph node:LN-AX-R',
#  'Lymph node:LN-ING-L',
#  'Lymph node:LN-MES',
#  'Lymph node:NA',
#  'Ovary',
#  'PBMC',
#  'Sex Organ:Ovary',
#  'Sex Organ:Sex-Organ',
#  'Sex Organ:Testis',
#  'Skin',
#  'Skin:Non-Rash',
#  'Skin:Rash',
#  'SpinalCord',
#  'Spleen',
#  'Testis',
#  'Whole blood'}

# %%
all_bulk_anndata = all_bulk_anndata[all_bulk_anndata.obs['dpi_time'] >= 0,]
all_bulk_anndata = all_bulk_anndata[all_bulk_anndata.obs['full.tissue'].isin(['Skin','Skin:Non-Rash','Skin:Rash'])]

# %%
all_bulk_anndata.var.gene = all_bulk_anndata.var.gene.astype(str)
all_bulk_anndata.var = all_bulk_anndata.var.set_index('gene')
# Out:
# Trying to set attribute `.var` of view, copying.

# %%
ddp = DeconvolutionDatasetParametrization()
ddp.feature_selection_method = 'overdispersed_bulk_and_high_sc'
ddp.verbose=False


ebov_dataset = DeconvolutionDataset(
    sc_anndata = sc_anndata,
    sc_celltype_col = "Abbreviation",
    bulk_anndata = all_bulk_anndata,
    bulk_time_col = "dpi_time",
    dtype_np = dtype_np,
    dtype = dtype,
    device=device,

    
    parametrization = ddp,
)
# Out:
# /home/nbarkas/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_ridge.py:147: LinAlgWarning: Ill-conditioned matrix (rcond=2.13916e-10): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True,

# %% [markdown]
# # Run Deconvolution

# %%
hyperparameters = TimeRegularizedDeconvolutionModelParametrization()
trajectory_hyperparameters = TimeRegularizedDeconvolutionGPParametrization()


pseudo_time_reg_deconv = TimeRegularizedDeconvolutionModel(
    dataset=ebov_dataset,
    trajectory_model_type='gp',
    device=device,
    dtype=dtype,
    hyperparameters = hyperparameters,
    trajectory_hyperparameters = trajectory_hyperparameters,

)

# %%
pseudo_time_reg_deconv.fit_model(n_iters=n_iters, verbose=True, log_frequency=1000, clear_param_store=False)
# Out:
# [step: 0, time: 1 s ] loss: 14169219.65
# [step: 1000, time: 14 s ] loss: 4832854.44
# [step: 2000, time: 26 s ] loss: 1924210.31
# [step: 3000, time: 39 s ] loss: 1009216.24
# [step: 4000, time: 52 s ] loss: 700029.04
# [step: 5000, time: 65 s ] loss: 573055.59
# [step: 6000, time: 78 s ] loss: 513330.86
# [step: 7000, time: 91 s ] loss: 482824.29
# [step: 8000, time: 104 s ] loss: 466499.94
# [step: 9000, time: 117 s ] loss: 457515.23
# [step: 10000, time: 129 s ] loss: 452528.09
# [step: 11000, time: 142 s ] loss: 449532.40
# [step: 12000, time: 155 s ] loss: 447738.58
# [step: 13000, time: 168 s ] loss: 446530.95
# [step: 14000, time: 181 s ] loss: 445691.96
# [step: 15000, time: 194 s ] loss: 444998.17
# [step: 16000, time: 207 s ] loss: 444456.88
# [step: 17000, time: 220 s ] loss: 444142.36
# [step: 18000, time: 233 s ] loss: 443971.54
# [step: 19000, time: 246 s ] loss: 443905.09

# %% [markdown]
# # Examine Outputs

# %%
# Plot the loses
pseudo_time_reg_deconv.plot_loss()
# Out:
# <AxesSubplot:title={'center':'Losses'}, xlabel='iteration', ylabel='ELBO Loss'>

# %%
pyro.get_param_store().keys()
# Out:
# dict_keys(['log_phi_posterior_loc_g', 'log_beta_posterior_loc_g', 'gp.f_loc', 'gp.f_scale_tril', 'f_posterior_loc_mc', 'f_posterior_scale_mc', 'gp.kernel.kern0.lengthscale', 'gp.kernel.kern0.variance', 'gp.kernel.kern1.variance', 'gp_f_mean_c'])

# %%
pseudo_time_reg_deconv.plot_composition_trajectories()

# %%
#pseudo_time_reg_deconv.plot_composition_trajectories(show_sampled_trajectories = True, n_samples=500)

# %%
pseudo_time_reg_deconv.plot_sample_compositions_scatter()

# %%
# Do correlation between different cell types

# %%
pseudo_time_reg_deconv.plot_sample_compositions_boxplot()
matplotlib.pyplot.show()

# %%
from ternadecov.deconvolution_plotter import *
decov_plotter = DeconvolutionPlotter(pseudo_time_reg_deconv)
decov_plotter.plot_sample_compositions_boxplot_confidence(verbose=True, spacing=3)
# Out:
# Processing Adipo
# Processing Endo
# Processing Keratinocyte
# Processing Macro
# Processing Mast
# Processing Melanocyte
# Processing NK
# Processing Pericyte
# Processing SMC
# Processing Schwann
# Processing Sebocyte
# Processing Stromal
# Processing TC
# /mnt/disk1/nbarkas/work/deconvolution_method/temporal-rna-seq-deconvolution/ternadecov/deconvolution_plotter.py:110: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()
